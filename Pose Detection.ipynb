# %%
# Import all necessary libraries
import cv2
import mediapipe as mp

# %%
# Identify webcam
cap = cv2.VideoCapture(0)  #Local webcam - 0, External webcam - 1

# %%
# Switch on webcam

while True:
    _, img = cap.read()  # switch on
    
    cv2.imshow("Eddie's Pose Detection", img)
    if cv2.waitKey(1) & 0xff == ord('r'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Leveraging the Mediapie library used for pose detection
mpPose = mp.solutions.pose
pose = mpPose.Pose()
'''pose = mpPose.Pose(static_image_mode = False, upper_body_only = False, smooth_landmarks=True, min_detection_confidence=0.5, 
                   min_tracking_confidence=0.5)'''

# To draw and connect the landmark
mpdrawing = mp.solutions.drawing_utils

# %%
# Switch on webcam and apply

while True:
    _, img = cap.read()  # switch on
    
    # convert image from BGR to RGB
    imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # Apply the mediapipe pose detection module for detection
    results = pose.process(imgRGB)
    #print(results.pose_landmarks) - shows landmark and none when nothing is detected
    
    # Draw landmarks
    if results.pose_landmarks:
        mpdrawing.draw_landmarks(img, results.pose_landmarks, mpPose.POSE_CONNECTIONS)
        
        
    cv2.putText(img, "Eddie's Pose Detection", (10, 50), cv2.FONT_HERSHEY_PLAIN, 3, (0,0,0),2)
    cv2.imshow("Eddie's Pose Detection", img)
    if cv2.waitKey(1) & 0xff == ord('r'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Import Python Imaging Library to display image
from PIL import Image

# %%
pose_dec = Image.open(r"C:\Users\user\Pictures\CV images\Pose Detection.PNG")
pose_dec
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=523x416 at 0x26F42790C40>

# %% [markdown]
#  See video at https://www.linkedin.com/in/edidiong-udoh-924503187/
